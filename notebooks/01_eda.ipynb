# %% [markdown]
# # Fase 1 · Análisis Exploratorio de Datos (EDA)
#
# ## Objetivo
#
# El objetivo de esta fase es realizar una exploración inicial del dataset **DataCo Smart Supply Chain**, el cual simula las operaciones comerciales, logísticas y de cadena de suministro de una organización global. Esta revisión permite comprender la estructura multidimensional de los datos, evaluar su calidad y detectar posibles inconsistencias o sesgos que puedan afectar a las fases posteriores de modelado predictivo y analítica avanzada.
#
# En esta etapa nos centramos en:
#
# - **Identificar las dimensiones operativas:** Clasificar y entender las variables comerciales (ventas, clientes), logísticas (modos de envío, tiempos de entrega) y de seguridad (estados de órdenes y alertas de fraude).
# - **Analizar la consistencia estructural:** Evaluar las dimensiones del dataset, los tipos de datos (fechas, variables categóricas, numéricas) y la coherencia interna entre registros relacionados.
# - **Evaluar la calidad de los datos:** Detectar la presencia de valores nulos, registros duplicados, inconsistencias en las coordenadas geográficas y datos potencialmente sensibles o expuestos.
# - **Explorar variables críticas del negocio:** Analizar el comportamiento de métricas clave como los días de envío reales frente a los estimados (`SLA`), los patrones de fraude en los métodos de pago y la distribución de ventas por regiones.
# - **Anticipar necesidades de ingeniería de características:** Identificar requerimientos específicos de limpieza, normalización de columnas, transformación de variables temporales y preparación de datos para la fase ETL.
#
# Este análisis proporciona una base sólida para definir la estrategia de preparación de datos, asegurando un pipeline robusto para la toma de decisiones estratégicas en la cadena de suministro.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
import sys
import os # Esto sube un nivel en las carpetas para encontrar la raíz del proyecto
sys.path.append(os.path.abspath(os.path.join('..')))
import src.exploration as e

# %%
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_data = pd.read_csv("../files/raw/dataco_supply_chain.csv", sep=None, engine="python", encoding="latin-1")

# %%
e.info_df(df_data)
# Out:
# ================================================================================
# INFORME TÉCNICO DEL DATAFRAME
# ================================================================================
#
# 🔹 Dimensiones:
# - Filas: 180519
# - Columnas: 53
#
# 🔹 Info general:
# <class 'pandas.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  str
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  str
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  str
#  9   Customer City                  180519 non-null  str
#  10  Customer Country               180519 non-null  str
#  11  Customer Email                 180519 non-null  str
#  12  Customer Fname                 180519 non-null  str
#  13  Customer Id                    180519 non-null  int64
#  14  Customer Lname                 180511 non-null  str
#  15  Customer Password              180519 non-null  str
#  16  Customer Segment               180519 non-null  str
#  17  Customer State                 180519 non-null  str
#  18  Customer Street                180519 non-null  str
#  19  Customer Zipcode               180516 non-null  float64
#  20  Department Id                  180519 non-null  int64
#  21  Department Name                180519 non-null  str
#  22  Latitude                       180519 non-null  float64
#  23  Longitude                      180519 non-null  float64
#  24  Market                         180519 non-null  str
#  25  Order City                     180519 non-null  str
#  26  Order Country                  180519 non-null  str
#  27  Order Customer Id              180519 non-null  int64
#  28  order date (DateOrders)        180519 non-null  str
#  29  Order Id                       180519 non-null  int64
#  30  Order Item Cardprod Id         180519 non-null  int64
#  31  Order Item Discount            180519 non-null  float64
#  32  Order Item Discount Rate       180519 non-null  float64
#  33  Order Item Id                  180519 non-null  int64
#  34  Order Item Product Price       180519 non-null  float64
#  35  Order Item Profit Ratio        180519 non-null  float64
#  36  Order Item Quantity            180519 non-null  int64
#  37  Sales                          180519 non-null  float64
#  38  Order Item Total               180519 non-null  float64
#  39  Order Profit Per Order         180519 non-null  float64
#  40  Order Region                   180519 non-null  str
#  41  Order State                    180519 non-null  str
#  42  Order Status                   180519 non-null  str
#  43  Order Zipcode                  24840 non-null   float64
#  44  Product Card Id                180519 non-null  int64
#  45  Product Category Id            180519 non-null  int64
#  46  Product Description            0 non-null       float64
#  47  Product Image                  180519 non-null  str
#  48  Product Name                   180519 non-null  str
#  49  Product Price                  180519 non-null  float64
#  50  Product Status                 180519 non-null  int64
#  51  shipping date (DateOrders)     180519 non-null  str
#  52  Shipping Mode                  180519 non-null  str
# dtypes: float64(15), int64(14), str(24)
# memory usage: 73.0 MB
#
# 🔹 Nulos:
# Type                               0.000000
# Days for shipping (real)           0.000000
# Days for shipment (scheduled)      0.000000
# Benefit per order                  0.000000
# Sales per customer                 0.000000
# Delivery Status                    0.000000
# Late_delivery_risk                 0.000000
# Category Id                        0.000000
# Category Name                      0.000000
# Customer City                      0.000000
# Customer Country                   0.000000
# Customer Email                     0.000000
# Customer Fname                     0.000000
# Customer Id                        0.000000
# Customer Lname                     0.004432
# Customer Password                  0.000000
# Customer Segment                   0.000000
# Customer State                     0.000000
# Customer Street                    0.000000
# Customer Zipcode                   0.001662
# Department Id                      0.000000
# Department Name                    0.000000
# Latitude                           0.000000
# Longitude                          0.000000
# Market                             0.000000
# Order City                         0.000000
# Order Country                      0.000000
# Order Customer Id                  0.000000
# order date (DateOrders)            0.000000
# Order Id                           0.000000
# Order Item Cardprod Id             0.000000
# Order Item Discount                0.000000
# Order Item Discount Rate           0.000000
# Order Item Id                      0.000000
# Order Item Product Price           0.000000
# Order Item Profit Ratio            0.000000
# Order Item Quantity                0.000000
# Sales                              0.000000
# Order Item Total                   0.000000
# Order Profit Per Order             0.000000
# Order Region                       0.000000
# Order State                        0.000000
# Order Status                       0.000000
# Order Zipcode                     86.239676
# Product Card Id                    0.000000
# Product Category Id                0.000000
# Product Description              100.000000
# Product Image                      0.000000
# Product Name                       0.000000
# Product Price                      0.000000
# Product Status                     0.000000
# shipping date (DateOrders)         0.000000
# Shipping Mode                      0.000000
# dtype: float64
#
# 🔹 Duplicados:
# Total duplicados: 0
#
# 🔹 Descriptivo variables cualitativas:
#                              count unique  \
# Type                        180519      4
# Delivery Status             180519      4
# Category Name               180519     50
# Customer City               180519    563
# Customer Country            180519      2
# Customer Email              180519      1
# Customer Fname              180519    782
# Customer Lname              180511   1109
# Customer Password           180519      1
# Customer Segment            180519      3
# Customer State              180519     46
# Customer Street             180519   7458
# Department Name             180519     11
# Market                      180519      5
# Order City                  180519   3597
# Order Country               180519    164
# order date (DateOrders)     180519  65752
# Order Region                180519     23
# Order State                 180519   1089
# Order Status                180519      9
# Product Image               180519    118
# Product Name                180519    118
# shipping date (DateOrders)  180519  63701
# Shipping Mode               180519      4
#
#                                                                           top  \
# Type                                                                    DEBIT
# Delivery Status                                                 Late delivery
# Category Name                                                          Cleats
# Customer City                                                          Caguas
# Customer Country                                                      EE. UU.
# Customer Email                                                      XXXXXXXXX
# Customer Fname                                                           Mary
# Customer Lname                                                          Smith
# Customer Password                                                   XXXXXXXXX
# Customer Segment                                                     Consumer
# Customer State                                                             PR
# Customer Street                                       9126 Wishing Expressway
# Department Name                                                      Fan Shop
# Market                                                                  LATAM
# Order City                                                      Santo Domingo
# Order Country                                                  Estados Unidos
# order date (DateOrders)                                      10/25/2016 14:39
# Order Region                                                  Central America
# Order State                                                        Inglaterra
# Order Status                                                         COMPLETE
# Product Image               http://images.acmesports.sports/Perfect+Fitnes...
# Product Name                                 Perfect Fitness Perfect Rip Deck
# shipping date (DateOrders)                                     5/9/2015 18:02
# Shipping Mode                                                  Standard Class
#
#                               freq
# Type                         69295
# Delivery Status              98977
# Category Name                24551
# Customer City                66770
# Customer Country            111146
# Customer Email              180519
# Customer Fname               65150
# Customer Lname               64104
# Customer Password           180519
# Customer Segment             93504
# Customer State               69373
# Customer Street                122
# Department Name              66861
# Market                       51594
# Order City                    2211
# Order Country                24840
# order date (DateOrders)          5
# Order Region                 28341
# Order State                   6722
# Order Status                 59491
# Product Image                24515
# Product Name                 24515
# shipping date (DateOrders)      10
# Shipping Mode               107752
# 🔹 Descriptivo variables cuantitativas:
#                                   count      mean       std      min  \
# Days for shipping (real)       180519.0      3.50      1.62     0.00
# Days for shipment (scheduled)  180519.0      2.93      1.37     0.00
# Benefit per order              180519.0     21.97    104.43 -4274.98
# Sales per customer             180519.0    183.11    120.04     7.49
# Late_delivery_risk             180519.0      0.55      0.50     0.00
# Category Id                    180519.0     31.85     15.64     2.00
# Customer Id                    180519.0   6691.38   4162.92     1.00
# Customer Zipcode               180516.0  35921.13  37542.46   603.00
# Department Id                  180519.0      5.44      1.63     2.00
# Latitude                       180519.0     29.72      9.81   -33.94
# Longitude                      180519.0    -84.92     21.43  -158.03
# Order Customer Id              180519.0   6691.38   4162.92     1.00
# Order Id                       180519.0  36221.89  21045.38     1.00
# Order Item Cardprod Id         180519.0    692.51    336.45    19.00
# Order Item Discount            180519.0     20.66     21.80     0.00
# Order Item Discount Rate       180519.0      0.10      0.07     0.00
# Order Item Id                  180519.0  90260.00  52111.49     1.00
# Order Item Product Price       180519.0    141.23    139.73     9.99
# Order Item Profit Ratio        180519.0      0.12      0.47    -2.75
# Order Item Quantity            180519.0      2.13      1.45     1.00
# Sales                          180519.0    203.77    132.27     9.99
# Order Item Total               180519.0    183.11    120.04     7.49
# Order Profit Per Order         180519.0     21.97    104.43 -4274.98
# Order Zipcode                   24840.0  55426.13  31919.28  1040.00
# Product Card Id                180519.0    692.51    336.45    19.00
# Product Category Id            180519.0     31.85     15.64     2.00
# Product Description                 0.0       NaN       NaN      NaN
# Product Price                  180519.0    141.23    139.73     9.99
# Product Status                 180519.0      0.00      0.00     0.00
#
#                                     25%       50%        75%        max
# Days for shipping (real)           2.00      3.00       5.00       6.00
# Days for shipment (scheduled)      2.00      4.00       4.00       4.00
# Benefit per order                  7.00     31.52      64.80     911.80
# Sales per customer               104.38    163.99     247.40    1939.99
# Late_delivery_risk                 0.00      1.00       1.00       1.00
# Category Id                       18.00     29.00      45.00      76.00
# Customer Id                     3258.50   6457.00    9779.00   20757.00
# Customer Zipcode                 725.00  19380.00   78207.00   99205.00
# Department Id                      4.00      5.00       7.00      12.00
# Latitude                          18.27     33.14      39.28      48.78
# Longitude                        -98.45    -76.85     -66.37     115.26
# Order Customer Id               3258.50   6457.00    9779.00   20757.00
# Order Id                       18057.00  36140.00   54144.00   77204.00
# Order Item Cardprod Id           403.00    627.00    1004.00    1363.00
# Order Item Discount                5.40     14.00      29.99     500.00
# Order Item Discount Rate           0.04      0.10       0.16       0.25
# Order Item Id                  45130.50  90260.00  135389.50  180519.00
# Order Item Product Price          50.00     59.99     199.99    1999.99
# Order Item Profit Ratio            0.08      0.27       0.36       0.50
# Order Item Quantity                1.00      1.00       3.00       5.00
# Sales                            119.98    199.92     299.95    1999.99
# Order Item Total                 104.38    163.99     247.40    1939.99
# Order Profit Per Order             7.00     31.52      64.80     911.80
# Order Zipcode                  23464.00  59405.00   90008.00   99301.00
# Product Card Id                  403.00    627.00    1004.00    1363.00
# Product Category Id               18.00     29.00      45.00      76.00
# Product Description                 NaN       NaN        NaN        NaN
# Product Price                     50.00     59.99     199.99    1999.99
# Product Status                     0.00      0.00       0.00       0.00
# 🔹 Muestra del dataframe:
#            Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 163930    DEBIT                         5                              4
# 74896      CASH                         4                              2
# 32981   PAYMENT                         4                              2
# 48530     DEBIT                         6                              2
# 112064  PAYMENT                         0                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 163930              12.37           49.480000     Late delivery
# 74896               59.16          173.990005     Late delivery
# 32981               57.59          191.949997     Late delivery
# 48530               26.25          104.989998     Late delivery
# 112064               6.37           84.970001  Shipping on time
#
#         Late_delivery_risk  Category Id         Category Name Customer City  \
# 163930                   1           40           Accessories          Troy
# 74896                    1           48          Water Sports      Glenview
# 32981                    1           35           Golf Gloves      New York
# 48530                    1            2                Soccer       Chicago
# 112064                   0           46  Indoor/Outdoor Games     Tonawanda
#
#        Customer Country Customer Email Customer Fname  Customer Id  \
# 163930          EE. UU.      XXXXXXXXX          Linda         8920
# 74896           EE. UU.      XXXXXXXXX           Mary         1793
# 32981           EE. UU.      XXXXXXXXX           Lisa         5298
# 48530           EE. UU.      XXXXXXXXX        Deborah         1864
# 112064          EE. UU.      XXXXXXXXX           Mary         4458
#
#        Customer Lname Customer Password Customer Segment Customer State  \
# 163930          Smith         XXXXXXXXX      Home Office             MI
# 74896           Burke         XXXXXXXXX         Consumer             IL
# 32981           Moore         XXXXXXXXX         Consumer             NY
# 48530           Smith         XXXXXXXXX        Corporate             IL
# 112064          Smith         XXXXXXXXX         Consumer             NY
#
#                  Customer Street  Customer Zipcode  Department Id  \
# 163930          5687 Heather Key           48098.0              6
# 74896             141 Dewy Plaza           60025.0              7
# 32981   1663 Hidden Brook Island           10040.0              6
# 48530        6324 Jagged Orchard           60647.0              2
# 112064          2122 Hazy Corner           14150.0              7
#
#        Department Name   Latitude  Longitude        Market   Order City  \
# 163930        Outdoors  42.580460 -83.156013         LATAM  Santa Clara
# 74896         Fan Shop  42.068680 -87.763115  Pacific Asia       Riyadh
# 32981         Outdoors  40.858891 -73.931068  Pacific Asia      Kocaeli
# 48530          Fitness  41.777691 -87.742645        Europe   Strasbourg
# 112064        Fan Shop  43.013969 -78.879066        Africa    Kisangani
#
#                           Order Country  Order Customer Id  \
# 163930                             Cuba               8920
# 74896                      Arabia Saudí               1793
# 32981                           Turquía               5298
# 48530                           Francia               1864
# 112064  República Democrática del Congo               4458
#
#        order date (DateOrders)  Order Id  Order Item Cardprod Id  \
# 163930           1/8/2015 6:28       499                     906
# 74896          8/29/2016 13:30     41553                    1073
# 32981          9/24/2016 23:38     43363                     771
# 48530          8/20/2017 11:37     65935                      19
# 112064         11/25/2016 2:52     47551                    1014
#
#         Order Item Discount  Order Item Discount Rate  Order Item Id  \
# 163930                 0.50                      0.01           1232
# 74896                 26.00                      0.13         103727
# 32981                  8.00                      0.04         108326
# 48530                 20.00                      0.16         164778
# 112064                14.99                      0.15         118874
#
#         Order Item Product Price  Order Item Profit Ratio  \
# 163930                 24.990000                     0.25
# 74896                 199.990005                     0.34
# 32981                  39.990002                     0.30
# 48530                 124.989998                     0.25
# 112064                 49.980000                     0.08
#
#         Order Item Quantity       Sales  Order Item Total  \
# 163930                    2   49.980000         49.480000
# 74896                     1  199.990005        173.990005
# 32981                     5  199.949997        191.949997
# 48530                     1  124.989998        104.989998
# 112064                    2   99.959999         84.970001
#
#         Order Profit Per Order    Order Region  \
# 163930                   12.37       Caribbean
# 74896                    59.16       West Asia
# 32981                    57.59       West Asia
# 48530                    26.25  Western Europe
# 112064                    6.37  Central Africa
#
#                             Order State     Order Status  Order Zipcode  \
# 163930                      Villa Clara         COMPLETE            NaN
# 74896                              Riad           CLOSED            NaN
# 32981                           Kocaeli  PENDING_PAYMENT            NaN
# 48530   Alsacia-Champaña-Ardenas-Lorena          ON_HOLD            NaN
# 112064               Provincia Oriental  PENDING_PAYMENT            NaN
#
#         Product Card Id  Product Category Id  Product Description  \
# 163930              906                   40                  NaN
# 74896              1073                   48                  NaN
# 32981               771                   35                  NaN
# 48530                19                    2                  NaN
# 112064             1014                   46                  NaN
#
#                                             Product Image  \
# 163930  http://images.acmesports.sports/Team+Golf+Tenn...
# 74896   http://images.acmesports.sports/Pelican+Sunstr...
# 32981   http://images.acmesports.sports/Clicgear+Rovic...
# 48530   http://images.acmesports.sports/Nike+Men%27s+F...
# 112064  http://images.acmesports.sports/O%27Brien+Men%...
#
#                                       Product Name  Product Price  \
# 163930  Team Golf Tennessee Volunteers Putter Grip      24.990000
# 74896                  Pelican Sunstream 100 Kayak     199.990005
# 32981                    Clicgear Rovic Cooler Bag      39.990002
# 48530      Nike Men's Fingertrap Max Training Shoe     124.989998
# 112064            O'Brien Men's Neoprene Life Vest      49.980000
#
#         Product Status shipping date (DateOrders)   Shipping Mode
# 163930               0             1/13/2015 6:28  Standard Class
# 74896                0             9/2/2016 13:30    Second Class
# 32981                0            9/28/2016 23:38    Second Class
# 48530                0            8/26/2017 11:37    Second Class
# 112064               0           11/25/2016 14:52        Same Day

# %%
df_data.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   Customer Country Customer Email Customer Fname  Customer Id Customer Lname  \
# 0      Puerto Rico      XXXXXXXXX          Cally        20755       Holloway
# 1      Puerto Rico      XXXXXXXXX          Irene        19492           Luna
# 2          EE. UU.      XXXXXXXXX        Gillian        19491      Maldonado
# 3          EE. UU.      XXXXXXXXX           Tana        19490           Tate
# 4      Puerto Rico      XXXXXXXXX           Orli        19489      Hendricks
#
#   Customer Password Customer Segment Customer State           Customer Street  \
# 0         XXXXXXXXX         Consumer             PR  5365 Noble Nectar Island
# 1         XXXXXXXXX         Consumer             PR          2679 Rustic Loop
# 2         XXXXXXXXX         Consumer             CA      8510 Round Bear Gate
# 3         XXXXXXXXX      Home Office             CA           3200 Amber Bend
# 4         XXXXXXXXX        Corporate             PR  8671 Iron Anchor Corners
#
#    Customer Zipcode  Department Id Department Name   Latitude   Longitude  \
# 0             725.0              2         Fitness  18.251453  -66.037056
# 1             725.0              2         Fitness  18.279451  -66.037064
# 2           95125.0              2         Fitness  37.292233 -121.881279
# 3           90027.0              2         Fitness  34.125946 -118.291016
# 4             725.0              2         Fitness  18.253769  -66.037048
#
#          Market  Order City Order Country  Order Customer Id  \
# 0  Pacific Asia      Bekasi     Indonesia              20755
# 1  Pacific Asia     Bikaner         India              19492
# 2  Pacific Asia     Bikaner         India              19491
# 3  Pacific Asia  Townsville     Australia              19490
# 4  Pacific Asia  Townsville     Australia              19489
#
#   order date (DateOrders)  Order Id  Order Item Cardprod Id  \
# 0         1/31/2018 22:56     77202                    1360
# 1         1/13/2018 12:27     75939                    1360
# 2         1/13/2018 12:06     75938                    1360
# 3         1/13/2018 11:45     75937                    1360
# 4         1/13/2018 11:24     75936                    1360
#
#    Order Item Discount  Order Item Discount Rate  Order Item Id  \
# 0            13.110000                      0.04         180517
# 1            16.389999                      0.05         179254
# 2            18.030001                      0.06         179253
# 3            22.940001                      0.07         179252
# 4            29.500000                      0.09         179251
#
#    Order Item Product Price  Order Item Profit Ratio  Order Item Quantity  \
# 0                    327.75                     0.29                    1
# 1                    327.75                    -0.80                    1
# 2                    327.75                    -0.80                    1
# 3                    327.75                     0.08                    1
# 4                    327.75                     0.45                    1
#
#     Sales  Order Item Total  Order Profit Per Order    Order Region  \
# 0  327.75        314.640015               91.250000  Southeast Asia
# 1  327.75        311.359985             -249.089996      South Asia
# 2  327.75        309.720001             -247.779999      South Asia
# 3  327.75        304.809998               22.860001         Oceania
# 4  327.75        298.250000              134.210007         Oceania
#
#        Order State     Order Status  Order Zipcode  Product Card Id  \
# 0  Java Occidental         COMPLETE            NaN             1360
# 1         Rajastán          PENDING            NaN             1360
# 2         Rajastán           CLOSED            NaN             1360
# 3       Queensland         COMPLETE            NaN             1360
# 4       Queensland  PENDING_PAYMENT            NaN             1360
#
#    Product Category Id  Product Description  \
# 0                   73                  NaN
# 1                   73                  NaN
# 2                   73                  NaN
# 3                   73                  NaN
# 4                   73                  NaN
#
#                                   Product Image  Product Name  Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch          327.75
#
#    Product Status shipping date (DateOrders)   Shipping Mode
# 0               0             2/3/2018 22:56  Standard Class
# 1               0            1/18/2018 12:27  Standard Class
# 2               0            1/17/2018 12:06  Standard Class
# 3               0            1/16/2018 11:45  Standard Class
# 4               0            1/15/2018 11:24  Standard Class

# %%
df_data[df_data["Customer Id"] == 4598].head() #para corroborar que la latitud y longitud pertenecen al cliente, no a la tienda.
# Out:
#            Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 51273     DEBIT                         5                              4
# 94210     DEBIT                         3                              4
# 112780  PAYMENT                         3                              4
# 128013    DEBIT                         3                              4
# 128025    DEBIT                         3                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 51273           19.670000          110.489998     Late delivery
# 94210          104.150002          371.980011  Advance shipping
# 112780          77.370003          179.929993  Advance shipping
# 128013          25.070000           75.980003  Advance shipping
# 128025          -4.500000           90.000000  Advance shipping
#
#         Late_delivery_risk  Category Id         Category Name Customer City  \
# 51273                    1           32          Golf Apparel        Aurora
# 94210                    0           45               Fishing        Aurora
# 112780                   0           46  Indoor/Outdoor Games        Aurora
# 128013                   0           29         Shop By Sport        Aurora
# 128025                   0           24       Women's Apparel        Aurora
#
#        Customer Country Customer Email Customer Fname  Customer Id  \
# 51273           EE. UU.      XXXXXXXXX         Gloria         4598
# 94210           EE. UU.      XXXXXXXXX         Gloria         4598
# 112780          EE. UU.      XXXXXXXXX         Gloria         4598
# 128013          EE. UU.      XXXXXXXXX         Gloria         4598
# 128025          EE. UU.      XXXXXXXXX         Gloria         4598
#
#        Customer Lname Customer Password Customer Segment Customer State  \
# 51273          Castro         XXXXXXXXX         Consumer             CO
# 94210          Castro         XXXXXXXXX         Consumer             CO
# 112780         Castro         XXXXXXXXX         Consumer             CO
# 128013         Castro         XXXXXXXXX         Consumer             CO
# 128025         Castro         XXXXXXXXX         Consumer             CO
#
#        Customer Street  Customer Zipcode  Department Id Department Name  \
# 51273   7489 Stony End           80013.0              6        Outdoors
# 94210   7489 Stony End           80013.0              7        Fan Shop
# 112780  7489 Stony End           80013.0              7        Fan Shop
# 128013  7489 Stony End           80013.0              5            Golf
# 128025  7489 Stony End           80013.0              5            Golf
#
#          Latitude  Longitude        Market Order City Order Country  \
# 51273  -33.937553  18.571438        Europe  Vallauris       Francia
# 94210  -33.937553  18.571438  Pacific Asia  Melbourne     Australia
# 112780 -33.937553  18.571438  Pacific Asia      Rasht          Irán
# 128013 -33.937553  18.571438  Pacific Asia  Melbourne     Australia
# 128025 -33.937553  18.571438  Pacific Asia  Melbourne     Australia
#
#         Order Customer Id order date (DateOrders)  Order Id  \
# 51273                4598          7/20/2017 5:31     63794
# 94210                4598         1/13/2016 19:16     25882
# 112780               4598        10/19/2016 18:52     45062
# 128013               4598         1/13/2016 19:16     25882
# 128025               4598         1/13/2016 19:16     25882
#
#         Order Item Cardprod Id  Order Item Discount  Order Item Discount Rate  \
# 51273                      715                19.50                      0.15
# 94210                     1004                28.00                      0.07
# 112780                    1014                19.99                      0.10
# 128013                     627                 4.00                      0.05
# 128025                     502                10.00                      0.10
#
#         Order Item Id  Order Item Product Price  Order Item Profit Ratio  \
# 51273          159455                129.990005                     0.18
# 94210           64788                399.980011                     0.28
# 112780         112514                 49.980000                     0.43
# 128013          64787                 39.990002                     0.33
# 128025          64786                 50.000000                    -0.05
#
#         Order Item Quantity       Sales  Order Item Total  \
# 51273                     1  129.990005        110.489998
# 94210                     1  399.980011        371.980011
# 112780                    4  199.919998        179.929993
# 128013                    2   79.980003         75.980003
# 128025                    2  100.000000         90.000000
#
#         Order Profit Per Order    Order Region                Order State  \
# 51273                19.670000  Western Europe  Provenza-Alpes-Costa Azul
# 94210               104.150002         Oceania                   Victoria
# 112780               77.370003      South Asia                     Guilán
# 128013               25.070000         Oceania                   Victoria
# 128025               -4.500000         Oceania                   Victoria
#
#           Order Status  Order Zipcode  Product Card Id  Product Category Id  \
# 51273         COMPLETE            NaN              715                   32
# 94210         COMPLETE            NaN             1004                   45
# 112780  PAYMENT_REVIEW            NaN             1014                   46
# 128013        COMPLETE            NaN              627                   29
# 128025        COMPLETE            NaN              502                   24
#
#         Product Description  \
# 51273                   NaN
# 94210                   NaN
# 112780                  NaN
# 128013                  NaN
# 128025                  NaN
#
#                                             Product Image  \
# 51273   http://images.acmesports.sports/TaylorMade+Wom...
# 94210   http://images.acmesports.sports/Field+%26+Stre...
# 112780  http://images.acmesports.sports/O%27Brien+Men%...
# 128013  http://images.acmesports.sports/Under+Armour+G...
# 128025  http://images.acmesports.sports/Nike+Men%27s+D...
#
#                                          Product Name  Product Price  \
# 51273                TaylorMade Women's RBZ SL Rescue     129.990005
# 94210       Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 112780               O'Brien Men's Neoprene Life Vest      49.980000
# 128013  Under Armour Girls' Toddler Spine Surge Runni      39.990002
# 128025           Nike Men's Dri-FIT Victory Golf Polo      50.000000
#
#         Product Status shipping date (DateOrders)   Shipping Mode
# 51273                0             7/25/2017 5:31  Standard Class
# 94210                0            1/16/2016 19:16  Standard Class
# 112780               0           10/22/2016 18:52  Standard Class
# 128013               0            1/16/2016 19:16  Standard Class
# 128025               0            1/16/2016 19:16  Standard Class

# %%
df_data.groupby("Department Id")["Order Id"].value_counts().sort_values(ascending=False).head(10)
# Out:
# Department Id  Order Id
# 5              31242       5
# 7              58549       5
#                5443        5
#                25752       5
#                26862       5
#                55052       5
#                56068       5
#                52950       5
#                33118       5
#                25135       5
# Name: count, dtype: int64

# %%
df_data[df_data["Department Id"] == 5].sample(5) #para corroborar que la latitud y longitud pertenecen al cliente, no a la tienda.
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 29192    PAYMENT                         1                              0
# 31333   TRANSFER                         2                              4
# 117517  TRANSFER                         0                              0
# 56950      DEBIT                         4                              4
# 28984    PAYMENT                         1                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 29192           98.000000          200.000000     Late delivery
# 31333           23.590000          212.500000  Advance shipping
# 117517           6.800000           75.580002  Shipping on time
# 56950           17.719999          141.750000  Shipping on time
# 28984           21.600000           45.000000     Late delivery
#
#         Late_delivery_risk  Category Id    Category Name Customer City  \
# 29192                    1           24  Women's Apparel      Brooklyn
# 31333                    0           24  Women's Apparel        Caguas
# 117517                   0           29    Shop By Sport       Wheaton
# 56950                    0           24  Women's Apparel        Caguas
# 28984                    1           24  Women's Apparel         Bronx
#
#        Customer Country Customer Email Customer Fname  Customer Id  \
# 29192           EE. UU.      XXXXXXXXX           Mary        12232
# 31333       Puerto Rico      XXXXXXXXX        Madison         3188
# 117517          EE. UU.      XXXXXXXXX        Kenneth         4432
# 56950       Puerto Rico      XXXXXXXXX           Mary         4761
# 28984           EE. UU.      XXXXXXXXX           Mary         6156
#
#        Customer Lname Customer Password Customer Segment Customer State  \
# 29192           Moore         XXXXXXXXX        Corporate             NY
# 31333             Ray         XXXXXXXXX      Home Office             PR
# 117517      Gillespie         XXXXXXXXX         Consumer             IL
# 56950         Shannon         XXXXXXXXX         Consumer             PR
# 28984       Hernandez         XXXXXXXXX        Corporate             NY
#
#                    Customer Street  Customer Zipcode  Department Id  \
# 29192   5735 Quaking Cider Highway           11216.0              5
# 31333           9276 Jagged Towers             725.0              5
# 117517           4294 High Passage           60187.0              5
# 56950            8289 Emerald Pike             725.0              5
# 28984   5918 Golden Beacon Freeway           10461.0              5
#
#        Department Name   Latitude  Longitude        Market     Order City  \
# 29192             Golf  40.679138 -73.944054          USCA   Fayetteville
# 31333             Golf  18.297707 -66.370560         LATAM         Juárez
# 117517            Golf  41.865440 -88.109901  Pacific Asia  Visakhapatnam
# 56950             Golf  18.244875 -66.370598          USCA           Kent
# 28984             Golf  40.846256 -73.847252         LATAM   Buenos Aires
#
#          Order Country  Order Customer Id order date (DateOrders)  Order Id  \
# 29192   Estados Unidos              12232          5/7/2016 21:44     33767
# 31333           México               3188         6/12/2017 21:20     61236
# 117517           India               4432          12/3/2015 7:35     23040
# 56950   Estados Unidos               4761         6/16/2016 16:46     36493
# 28984        Argentina               6156         5/18/2017 17:00     59511
#
#         Order Item Cardprod Id  Order Item Discount  Order Item Discount Rate  \
# 29192                      502                 0.00                      0.00
# 31333                      502                37.50                      0.15
# 117517                     627                 4.40                      0.06
# 56950                      502                 8.25                      0.06
# 28984                      502                 5.00                      0.10
#
#         Order Item Id  Order Item Product Price  Order Item Profit Ratio  \
# 29192           84270                 50.000000                     0.49
# 31333          153168                 50.000000                     0.11
# 117517          57693                 39.990002                     0.09
# 56950           91117                 50.000000                     0.13
# 28984          148951                 50.000000                     0.48
#
#         Order Item Quantity       Sales  Order Item Total  \
# 29192                     4  200.000000        200.000000
# 31333                     5  250.000000        212.500000
# 117517                    2   79.980003         75.580002
# 56950                     3  150.000000        141.750000
# 28984                     1   50.000000         45.000000
#
#         Order Profit Per Order     Order Region         Order State  \
# 29192                98.000000   South of  USA   Carolina del Norte
# 31333                23.590000  Central America           Chihuahua
# 117517                6.800000       South Asia      Andhra Pradesh
# 56950                17.719999     West of USA           Washington
# 28984                21.600000    South America        Buenos Aires
#
#            Order Status  Order Zipcode  Product Card Id  Product Category Id  \
# 29192   PENDING_PAYMENT        28314.0              502                   24
# 31333           PENDING            NaN              502                   24
# 117517          PENDING            NaN              627                   29
# 56950          COMPLETE        98031.0              502                   24
# 28984   PENDING_PAYMENT            NaN              502                   24
#
#         Product Description  \
# 29192                   NaN
# 31333                   NaN
# 117517                  NaN
# 56950                   NaN
# 28984                   NaN
#
#                                             Product Image  \
# 29192   http://images.acmesports.sports/Nike+Men%27s+D...
# 31333   http://images.acmesports.sports/Nike+Men%27s+D...
# 117517  http://images.acmesports.sports/Under+Armour+G...
# 56950   http://images.acmesports.sports/Nike+Men%27s+D...
# 28984   http://images.acmesports.sports/Nike+Men%27s+D...
#
#                                          Product Name  Product Price  \
# 29192            Nike Men's Dri-FIT Victory Golf Polo      50.000000
# 31333            Nike Men's Dri-FIT Victory Golf Polo      50.000000
# 117517  Under Armour Girls' Toddler Spine Surge Runni      39.990002
# 56950            Nike Men's Dri-FIT Victory Golf Polo      50.000000
# 28984            Nike Men's Dri-FIT Victory Golf Polo      50.000000
#
#         Product Status shipping date (DateOrders)   Shipping Mode
# 29192                0              5/8/2016 9:44        Same Day
# 31333                0            6/14/2017 21:20  Standard Class
# 117517               0            12/3/2015 19:35        Same Day
# 56950                0            6/20/2016 16:46  Standard Class
# 28984                0             5/19/2017 5:00        Same Day

# %%
df_data.groupby("Customer Id")["Order Id"].value_counts().sort_values(ascending=False).head(10)
# Out:
# Customer Id  Order Id
# 2            57963       5
# 4995         58897       5
# 4996         36451       5
#              6717        5
# 4997         63047       5
# 4987         45977       5
#              30412       5
# 4989         11862       5
# 12425        48314       5
# 12426        32304       5
# Name: count, dtype: int64

# %%
df_data["shipping date (DateOrders)"].value_counts()
# Out:
# shipping date (DateOrders)
# 5/9/2015 18:02      10
# 9/27/2015 20:28     10
# 9/24/2015 23:48     10
# 8/1/2015 18:37      10
# 11/15/2016 13:45    10
#                     ..
# 1/27/2016 18:59      1
# 1/28/2016 19:25      1
# 1/26/2016 6:49       1
# 1/23/2016 7:10       1
# 1/21/2016 5:56       1
# Name: count, Length: 63701, dtype: int64

# %%
df_data["Shipping Mode"].value_counts()
# Out:
# Shipping Mode
# Standard Class    107752
# Second Class       35216
# First Class        27814
# Same Day            9737
# Name: count, dtype: int64

# %%
df_data["Customer Country"].value_counts()
# Out:
# Customer Country
# EE. UU.        111146
# Puerto Rico     69373
# Name: count, dtype: int64

# %%
df_data["Customer State"].unique()
# Out:
# <StringArray>
# [   'PR',    'CA',    'NY',    'FL',    'MA',    'IL',    'MT',    'PA',
#     'MI',    'TX',    'DE',    'GA',    'MD',    'OH',    'HI',    'NJ',
#     'WI',    'AZ',    'CO',    'MN',    'NC',    'NM',    'OR',    'SC',
#     'VA',    'UT',    'WA',    'KY',    'WV',    'RI',    'CT',    'LA',
#     'TN',    'DC',    'ND',    'MO',    'IN',    'ID',    'NV',    'KS',
#     'AR',    'OK',    'AL',    'IA', '95758', '91732']
# Length: 46, dtype: str

# %%
df_data["Order Status"].unique()
# Out:
# <StringArray>
# [       'COMPLETE',         'PENDING',          'CLOSED', 'PENDING_PAYMENT',
#         'CANCELED',      'PROCESSING', 'SUSPECTED_FRAUD',         'ON_HOLD',
#   'PAYMENT_REVIEW']
# Length: 9, dtype: str

# %%
df_data["Order Region"].unique()
# Out:
# <StringArray>
# [ 'Southeast Asia',      'South Asia',         'Oceania',    'Eastern Asia',
#        'West Asia',    'West of USA ',      'US Center ',     'West Africa',
#   'Central Africa',    'North Africa',  'Western Europe', 'Northern Europe',
#  'Central America',       'Caribbean',   'South America',     'East Africa',
#  'Southern Europe',     'East of USA',          'Canada', 'Southern Africa',
#     'Central Asia',  'Eastern Europe',  'South of  USA ']
# Length: 23, dtype: str

# %%
df_data["Market"].unique()
# Out:
# <StringArray>
# ['Pacific Asia', 'USCA', 'Africa', 'Europe', 'LATAM']
# Length: 5, dtype: str

# %%
df_data["Category Name"].unique()
# Out:
# <StringArray>
# [      'Sporting Goods',               'Cleats',        'Shop By Sport',
#       'Women's Apparel',          'Electronics',         'Boxing & MMA',
#      'Cardio Equipment',             'Trade-In',     'Kids' Golf Clubs',
#    'Hunting & Shooting',  'Baseball & Softball',       'Men's Footwear',
#      'Camping & Hiking', 'Consumer Electronics',             'Cameras ',
#             'Computers',           'Basketball',               'Soccer',
#        'Girls' Apparel',          'Accessories',     'Women's Clothing',
#                'Crafts',       'Men's Clothing',     'Tennis & Racquet',
#   'Fitness Accessories',      'As Seen on  TV!',           'Golf Balls',
#     'Strength Training',  'Children's Clothing',             'Lacrosse',
#                 'Baby ',              'Fishing',               'Books ',
#                  'DVDs',                 'CDs ',               'Garden',
#                'Hockey',         'Pet Supplies',    'Health and Beauty',
#                 'Music',          'Video Games',          'Golf Gloves',
#     'Golf Bags & Carts',           'Golf Shoes',         'Golf Apparel',
#    'Women's Golf Clubs',     'Men's Golf Clubs',                 'Toys',
#          'Water Sports', 'Indoor/Outdoor Games']
# Length: 50, dtype: str

# %%
df_data["Customer Segment"].unique()
# Out:
# <StringArray>
# ['Consumer', 'Home Office', 'Corporate']
# Length: 3, dtype: str

# %%
df_data.groupby("Customer State")["Order Zipcode"].unique()
# Out:
# Customer State
# 91732                                                [nan]
# 95758                                                [nan]
# AL                [nan, 60462.0, 98105.0, 7960.0, 22980.0]
# AR               [nan, 43130.0, 90032.0, 39212.0, 43302.0]
# AZ       [nan, 10035.0, 32216.0, 43229.0, 46368.0, 8001...
# CA       [nan, 95123.0, 19134.0, 31907.0, 77041.0, 2230...
# CO       [nan, 26003.0, 38109.0, 92024.0, 19134.0, 1002...
# CT       [nan, 89115.0, 19140.0, 95051.0, 90049.0, 7501...
# DC       [nan, 73120.0, 31907.0, 48227.0, 47201.0, 9203...
# DE       [nan, 43055.0, 60505.0, 90049.0, 90032.0, 7050...
# FL       [nan, 38109.0, 72401.0, 60610.0, 6708.0, 43017...
# GA       [nan, 10035.0, 97206.0, 98661.0, 87124.0, 7570...
# HI       [60016.0, nan, 75034.0, 13440.0, 89031.0, 1000...
# IA               [nan, 10011.0, 85023.0, 48911.0, 78041.0]
# ID               [nan, 38301.0, 48234.0, 20735.0, 19711.0]
# IL       [nan, 13021.0, 79762.0, 32216.0, 49201.0, 9811...
# IN       [nan, 37042.0, 60623.0, 94110.0, 10035.0, 7707...
# KS       [nan, 10024.0, 60623.0, 77041.0, 90032.0, 9408...
# KY       [nan, 34952.0, 10009.0, 19140.0, 3820.0, 10035...
# LA       [nan, 10011.0, 29203.0, 77095.0, 28540.0, 9512...
# MA       [nan, 33614.0, 97756.0, 33023.0, 37211.0, 7508...
# MD       [85234.0, 45231.0, nan, 98103.0, 27604.0, 8001...
# MI       [nan, 90045.0, 11550.0, 60610.0, 28314.0, 9412...
# MN       [nan, 30080.0, 92105.0, 77041.0, 90301.0, 3331...
# MO       [nan, 40475.0, 60623.0, 90036.0, 54601.0, 6580...
# MT                        [nan, 45373.0, 60653.0, 78745.0]
# NC       [nan, 98115.0, 65807.0, 32303.0, 75217.0, 9194...
# ND       [nan, 10550.0, 97477.0, 21215.0, 75081.0, 6061...
# NJ       [60126.0, nan, 35810.0, 30318.0, 19143.0, 9410...
# NM       [nan, 98105.0, 90032.0, 97477.0, 36116.0, 9412...
# NV       [nan, 32303.0, 90008.0, 94109.0, 92804.0, 8001...
# NY       [nan, 77041.0, 93727.0, 90049.0, 94122.0, 7709...
# OH       [85345.0, nan, 19143.0, 19711.0, 95037.0, 8502...
# OK       [nan, 10035.0, 28540.0, 50322.0, 60610.0, 9810...
# OR       [nan, 10009.0, 2138.0, 10035.0, 62301.0, 90036...
# PA       [nan, 23223.0, 43229.0, 21044.0, 28806.0, 7521...
# PR       [nan, 99301.0, 90049.0, 94110.0, 66212.0, 9810...
# RI       [nan, 28205.0, 53209.0, 90045.0, 53711.0, 4322...
# SC       [nan, 90036.0, 55901.0, 94109.0, 1841.0, 63116...
# TN       [nan, 90045.0, 19805.0, 10024.0, 63116.0, 9000...
# TX       [nan, 47201.0, 33801.0, 78577.0, 21215.0, 7220...
# UT       [nan, 60623.0, 94110.0, 24153.0, 90008.0, 1350...
# VA       [nan, 76106.0, 90004.0, 94110.0, 54880.0, 9000...
# WA       [nan, 38109.0, 74133.0, 94122.0, 23434.0, 9810...
# WI       [nan, 22801.0, 19134.0, 87105.0, 60623.0, 9203...
# WV       [nan, 10009.0, 10011.0, 92037.0, 10035.0, 9412...
# Name: Order Zipcode, dtype: object

# %%
df_token = pd.read_csv("../files/raw/tokenized_access_logs.csv")

# %%
e.info_df(df_token)
# Out:
# ================================================================================
# INFORME TÉCNICO DEL DATAFRAME
# ================================================================================
#
# 🔹 Dimensiones:
# - Filas: 469977
# - Columnas: 8
#
# 🔹 Info general:
# <class 'pandas.DataFrame'>
# RangeIndex: 469977 entries, 0 to 469976
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Product     469977 non-null  str
#  1   Category    469977 non-null  str
#  2   Date        469977 non-null  str
#  3   Month       469977 non-null  str
#  4   Hour        469977 non-null  int64
#  5   Department  469977 non-null  str
#  6   ip          469977 non-null  str
#  7   url         469977 non-null  str
# dtypes: int64(1), str(7)
# memory usage: 28.7 MB
#
# 🔹 Nulos:
# Product       0.0
# Category      0.0
# Date          0.0
# Month         0.0
# Hour          0.0
# Department    0.0
# ip            0.0
# url           0.0
# dtype: float64
#
# 🔹 Duplicados:
# Total duplicados: 3249
#
# 🔹 Descriptivo variables cualitativas:
#              count  unique                                                top  \
# Product     469977      76                   Perfect Fitness Perfect Rip Deck
# Category    469977      33                                             cleats
# Date        469977  160815                                    9/14/2017 20:34
# Month       469977       5                                                Sep
# Department  469977       6                                          outdoors
# ip          469977    3340                                      157.21.93.193
# url         469977     152  /department/apparel/category/cleats/product/Pe...
#
#               freq
# Product      27878
# Category     27878
# Date           156
# Month       137238
# Department   79926
# ip             566
# url          20258
# 🔹 Descriptivo variables cuantitativas:
#          count   mean   std  min   25%   50%   75%   max
# Hour  469977.0  14.59  5.57  0.0  10.0  15.0  20.0  23.0
# 🔹 Muestra del dataframe:
#                                               Product        Category  \
# 351058               Perfect Fitness Perfect Rip Deck          cleats
# 4948        adidas Men's Germany Black Crest Away Tee  girls' apparel
# 148764        Nike Men's Fingertrap Max Training Shoe          soccer
# 178603  Diamondback Boys' Insight 24 Performance Hybr      basketball
# 22630         Nike Men's Fingertrap Max Training Shoe          soccer
#
#                     Date Month  Hour Department              ip  \
# 351058    1/12/2018 9:02   Jan     9   apparel    173.219.18.85
# 4948    10/10/2017 15:38   Oct    15      golf    72.217.87.201
# 148764   11/4/2017 10:20   Nov    10   fitness   185.141.25.207
# 178603  12/20/2017 22:47   Dec    22   fitness   88.197.205.228
# 22630    1/31/2018 18:15   Jan    18   fitness     26.34.173.88
#
#                                                       url
# 351058  /department/apparel/category/cleats/product/Pe...
# 4948    /department/golf/category/girls'%20apparel/pro...
# 148764  /department/fitness/category/soccer/product/Ni...
# 178603  /department/fitness/category/basketball/produc...
# 22630   /department/fitness/category/soccer/product/Ni...

# %%
df_token["Month"].unique()
# Out:
# <StringArray>
# ['Sep', 'Oct', 'Dec', 'Jan', 'Nov']
# Length: 5, dtype: str

# %% [markdown]
# # Conclusiones finales del EDA · DataCo
#
# - **Calidad de Datos y Gestión de Nulos:** La integridad general del dataset es excelente en la mayoría de sus variables transaccionales y financieras. La excepción principal se concentra en la columna `Order Zipcode`, la cual presenta valores nulos que requieren una estrategia de imputación o limpieza en la fase ETL, dado que pueden afectar el análisis geoespacial del destino de las órdenes.
#
# - **Duplicados y Estructura Lógica:** Las repeticiones detectadas en los registros no constituyen errores de duplicidad aleatoria; se justifican plenamente por la estructura lógica y granular del dataset, donde un mismo número de orden (`Order Id`) puede contener múltiples ítems de productos individuales o registrar distintas actualizaciones en el historial de envío.
#
# - **Políticas de Privacidad y Reducción de Dimensiones (Eliminación):** Con el fin de optimizar el rendimiento del almacenamiento en el ecosistema de Big Data y garantizar el cumplimiento estricto de las normativas de protección de datos (debido a la naturaleza sintética/expuesta de cierta información), se determina la eliminación definitiva de las siguientes columnas no relevantes o sensibles:
#   - `Customer Email` (Privacidad)
#   - `Customer Password` (Seguridad)
#   - `Product Description` (Columna redundante o vacía en el catálogo de productos)
#   - `Order State` (Duplicidad con las métricas regionales o de envío)
#
# - **Estandarización y Corrección de Anomalías:** Se detectaron inconsistencias críticas en la columna de ubicación del cliente (`Customer State`). Mientras que la mayoría de los registros adoptan el formato estándar de código de estado de dos letras (ej. NY, TX), se identificaron códigos postales numéricos (como *95758* y *91732*) en dicho campo. Como acción obligatoria de limpieza, se plantea mapear y reemplazar estos números por el estado correcto al que pertenecen (`CA`).
#
# - **Optimización de Estructura y Formato de Columnas:** Dado que las columnas ya se encuentran en el idioma inglés, la transformación se centrará en estandarizar su formato de texto. Se aplicará una conversión estricta a minúsculas y se reemplazarán los espacios por guiones bajos (formato `snake_case`) para homogeneizar los nombres de las variables (ej. de `Order Id` a `order_id`). Asimismo, se transformarán las variables temporales desde texto plano a formato `datetime` nativo.
#
# - **Integración y Complementariedad:** Las tablas analizadas demuestran ser altamente complementarias para construir un modelo en estrella o copo de nieve, permitiendo cruzar de manera directa las dimensiones de Clientes, Productos y Geografía con la tabla de hechos de Órdenes y Envíos.
#
# ---
#
# Esta fase concluye con éxito, dejando una hoja de ruta clara, justificada y accionable para la siguiente etapa del pipeline: **Limpieza, Transformación y Carga (ETL)**.
