# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
import sys
import os # Esto sube un nivel en las carpetas para encontrar la raíz del proyecto
sys.path.append(os.path.abspath(os.path.join('..')))
import src.exploration as e
import src.transform as t

# %%
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_data = pd.read_csv("../files/raw/dataco_supply_chain.csv", sep=None, engine="python", encoding="latin-1")

# %%
df_data = t.standardize_columns(df_data)

# %%
df_data.sample(5)
# Out:
#             type  days_for_shipping_real  days_for_shipment_scheduled  \
# 73154      DEBIT                       2                            4
# 59735      DEBIT                       5                            4
# 65506      DEBIT                       5                            2
# 114530  TRANSFER                       5                            4
# 81013      DEBIT                       5                            4
#
#         benefit_per_order  sales_per_customer   delivery_status  \
# 73154           51.330002          163.990005  Advance shipping
# 59735           93.500000          339.980011     Late delivery
# 65506           48.139999          165.979996     Late delivery
# 114530        -468.559998          187.429993     Late delivery
# 81013           52.380001          193.990005     Late delivery
#
#         late_delivery_risk  category_id         category_name   customer_city  \
# 73154                    0           48          Water Sports          Caguas
# 59735                    1           45               Fishing        Brooklyn
# 65506                    1            9      Cardio Equipment      Long Beach
# 114530                   1           46  Indoor/Outdoor Games  East Brunswick
# 81013                    1           48          Water Sports     Simi Valley
#
#        customer_country customer_email customer_fname  customer_id  \
# 73154       Puerto Rico      XXXXXXXXX           Lori         3059
# 59735           EE. UU.      XXXXXXXXX           Adam         5266
# 65506           EE. UU.      XXXXXXXXX          Laura        11262
# 114530          EE. UU.      XXXXXXXXX         Lauren        10281
# 81013           EE. UU.      XXXXXXXXX          Julia         4794
#
#        customer_lname customer_password customer_segment customer_state  \
# 73154         Hensley         XXXXXXXXX        Corporate             PR
# 59735           Pratt         XXXXXXXXX        Corporate             NY
# 65506           Lopez         XXXXXXXXX         Consumer             CA
# 114530          Smith         XXXXXXXXX         Consumer             NJ
# 81013          Mosley         XXXXXXXXX         Consumer             CA
#
#               customer_street  customer_zipcode  department_id  \
# 73154   4429 Clear Panda Cove             725.0              7
# 59735        3193 Old Parkway           11219.0              7
# 65506          2 Middle Mall            90805.0              3
# 114530     2770 Hidden Villas            8816.0              7
# 81013      7832 Wishing Court           93063.0              7
#
#        department_name   latitude   longitude        market  \
# 73154         Fan Shop  18.200169  -66.370522        Africa
# 59735         Fan Shop  40.634663  -73.994804        Europe
# 65506         Footwear  33.767063 -118.189255        Europe
# 114530        Fan Shop  40.412552  -74.418327         LATAM
# 81013         Fan Shop  34.267914 -118.671211  Pacific Asia
#
#                  order_city order_country  order_customer_id  \
# 73154                Agadir     Marruecos               3059
# 59735                Trento        Italia               5266
# 65506                Galati       Rumania              11262
# 114530  Santana de Parnaíba        Brasil              10281
# 81013                  Ipoh       Malasia               4794
#
#        order_date_dateorders  order_id  order_item_cardprod_id  \
# 73154        12/21/2016 0:44     49326                    1073
# 59735        8/25/2015 16:08     16214                    1004
# 65506       11/29/2016 18:17     47869                     191
# 114530        1/21/2015 4:31      1384                    1014
# 81013        1/31/2016 20:38     27119                    1073
#
#         order_item_discount  order_item_discount_rate  order_item_id  \
# 73154                 36.00                      0.18         123308
# 59735                 60.00                      0.15          40474
# 65506                 34.00                      0.17         119700
# 114530                62.48                      0.25           3420
# 81013                  6.00                      0.03          67941
#
#         order_item_product_price  order_item_profit_ratio  \
# 73154                 199.990005                     0.31
# 59735                 399.980011                     0.28
# 65506                  99.989998                     0.29
# 114530                 49.980000                    -2.50
# 81013                 199.990005                     0.27
#
#         order_item_quantity       sales  order_item_total  \
# 73154                     1  199.990005        163.990005
# 59735                     1  399.980011        339.980011
# 65506                     2  199.979996        165.979996
# 114530                    5  249.899994        187.429993
# 81013                     1  199.990005        193.990005
#
#         order_profit_per_order     order_region           order_state  \
# 73154                51.330002     North Africa         Sus-Masa-Draa
# 59735                93.500000  Southern Europe  Trentino-Alto Adigio
# 65506                48.139999   Eastern Europe                Galati
# 114530             -468.559998    South America             São Paulo
# 81013                52.380001   Southeast Asia                 Perak
#
#        order_status  order_zipcode  product_card_id  product_category_id  \
# 73154      COMPLETE            NaN             1073                   48
# 59735      COMPLETE            NaN             1004                   45
# 65506      COMPLETE            NaN              191                    9
# 114530      PENDING            NaN             1014                   46
# 81013      COMPLETE            NaN             1073                   48
#
#         product_description  \
# 73154                   NaN
# 59735                   NaN
# 65506                   NaN
# 114530                  NaN
# 81013                   NaN
#
#                                             product_image  \
# 73154   http://images.acmesports.sports/Pelican+Sunstr...
# 59735   http://images.acmesports.sports/Field+%26+Stre...
# 65506   http://images.acmesports.sports/Nike+Men%27s+F...
# 114530  http://images.acmesports.sports/O%27Brien+Men%...
# 81013   http://images.acmesports.sports/Pelican+Sunstr...
#
#                                      product_name  product_price  \
# 73154                 Pelican Sunstream 100 Kayak     199.990005
# 59735   Field & Stream Sportsman 16 Gun Fire Safe     399.980011
# 65506           Nike Men's Free 5.0+ Running Shoe      99.989998
# 114530           O'Brien Men's Neoprene Life Vest      49.980000
# 81013                 Pelican Sunstream 100 Kayak     199.990005
#
#         product_status shipping_date_dateorders   shipping_mode
# 73154                0          12/23/2016 0:44  Standard Class
# 59735                0          8/30/2015 16:08  Standard Class
# 65506                0          12/4/2016 18:17    Second Class
# 114530               0           1/26/2015 4:31  Standard Class
# 81013                0           2/5/2016 20:38  Standard Class

# %%
# Convertimos la columna al formato datetime correcto
df_data['order_date_dateorders'] = pd.to_datetime(df_data['order_date_dateorders'])

# %%
# Esto te devolverá ambas fechas en una sola salida limpia

df_data['order_date_dateorders'].agg(['min', 'max'])
# Out:
# min   2015-01-01 00:00:00
# max   2018-01-31 23:38:00
# Name: order_date_dateorders, dtype: datetime64[us]

# %% [markdown]
# #### Eliminar columnas

# %%
df_data.drop(columns=["product_status", "customer_email", "customer_password", "product_description", "order_zipcode", "market", "order_state","product_image"],inplace=True)

# %% [markdown]
# #### Cambiar los códigos por abreviaturas del estado

# %%
dicc_ca = {"95758" : "CA", "91732" : "CA"}

df_data["customer_state"] = df_data["customer_state"].map(dicc_ca).fillna(df_data["customer_state"])

# %%
df_data["customer_state"].unique()
# Out:
# <StringArray>
# ['PR', 'CA', 'NY', 'FL', 'MA', 'IL', 'MT', 'PA', 'MI', 'TX', 'DE', 'GA', 'MD',
#  'OH', 'HI', 'NJ', 'WI', 'AZ', 'CO', 'MN', 'NC', 'NM', 'OR', 'SC', 'VA', 'UT',
#  'WA', 'KY', 'WV', 'RI', 'CT', 'LA', 'TN', 'DC', 'ND', 'MO', 'IN', 'ID', 'NV',
#  'KS', 'AR', 'OK', 'AL', 'IA']
# Length: 44, dtype: str

# %% [markdown]
# #### Convertir tipos de datos

# %%
df_data["customer_zipcode"] = df_data["customer_zipcode"].astype(str).str.replace(".0", "", regex=False)

# %%
df_data["order_item_discount"] = df_data["order_item_discount"].astype(float)

# %% [markdown]
# #### Rellenar los 3 nulos de la columna customer_zipcode usando la latitud y la longitud

# %%
# 1

df_data.loc[np.isclose(df_data["latitude"], 39.134159) & np.isclose(df_data["longitude"], -123.718552),"customer_zipcode"] = "95410"
 
# 2

df_data.loc[np.isclose(df_data["latitude"], 38.408573) & np.isclose(df_data["longitude"], -121.449112),"customer_zipcode"] = "95823"
 
# 3

df_data.loc[np.isclose(df_data["latitude"], 34.071892) & np.isclose(df_data["longitude"], -118.013886),"customer_zipcode"] = "91732"

# %% [markdown]
# #### Aplicar función para redondear los decimales

# %%
t.round_up(df_data)

df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer             PR  5365 Noble Nectar Island              725
# 1         Consumer             PR          2679 Rustic Loop              725
# 2         Consumer             CA      8510 Round Bear Gate            95125
# 3      Home Office             CA           3200 Amber Bend            90027
# 4        Corporate             PR  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755   2018-01-31 22:56:00     77202
# 1         India              19492   2018-01-13 12:27:00     75939
# 2         India              19491   2018-01-13 12:06:00     75938
# 3     Australia              19490   2018-01-13 11:45:00     75937
# 4     Australia              19489   2018-01-13 11:24:00     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price shipping_date_dateorders   shipping_mode
# 0  Smart watch          327.75           2/3/2018 22:56  Standard Class
# 1  Smart watch          327.75          1/18/2018 12:27  Standard Class
# 2  Smart watch          327.75          1/17/2018 12:06  Standard Class
# 3  Smart watch          327.75          1/16/2018 11:45  Standard Class
# 4  Smart watch          327.75          1/15/2018 11:24  Standard Class

# %% [markdown]
# #### Dividir una columna en dos, fecha y hora y cambiar el formato

# %%
df_data[['date', 'datetime']] = df_data['shipping_date_dateorders'].str.split(' ', expand=True)

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer             PR  5365 Noble Nectar Island              725
# 1         Consumer             PR          2679 Rustic Loop              725
# 2         Consumer             CA      8510 Round Bear Gate            95125
# 3      Home Office             CA           3200 Amber Bend            90027
# 4        Corporate             PR  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755   2018-01-31 22:56:00     77202
# 1         India              19492   2018-01-13 12:27:00     75939
# 2         India              19491   2018-01-13 12:06:00     75938
# 3     Australia              19490   2018-01-13 11:45:00     75937
# 4     Australia              19489   2018-01-13 11:24:00     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price shipping_date_dateorders   shipping_mode  \
# 0  Smart watch          327.75           2/3/2018 22:56  Standard Class
# 1  Smart watch          327.75          1/18/2018 12:27  Standard Class
# 2  Smart watch          327.75          1/17/2018 12:06  Standard Class
# 3  Smart watch          327.75          1/16/2018 11:45  Standard Class
# 4  Smart watch          327.75          1/15/2018 11:24  Standard Class
#
#         date datetime
# 0   2/3/2018    22:56
# 1  1/18/2018    12:27
# 2  1/17/2018    12:06
# 3  1/16/2018    11:45
# 4  1/15/2018    11:24

# %%
df_data.drop(columns=["shipping_date_dateorders"],inplace=True)

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer             PR  5365 Noble Nectar Island              725
# 1         Consumer             PR          2679 Rustic Loop              725
# 2         Consumer             CA      8510 Round Bear Gate            95125
# 3      Home Office             CA           3200 Amber Bend            90027
# 4        Corporate             PR  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755   2018-01-31 22:56:00     77202
# 1         India              19492   2018-01-13 12:27:00     75939
# 2         India              19491   2018-01-13 12:06:00     75938
# 3     Australia              19490   2018-01-13 11:45:00     75937
# 4     Australia              19489   2018-01-13 11:24:00     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price   shipping_mode       date datetime
# 0  Smart watch          327.75  Standard Class   2/3/2018    22:56
# 1  Smart watch          327.75  Standard Class  1/18/2018    12:27
# 2  Smart watch          327.75  Standard Class  1/17/2018    12:06
# 3  Smart watch          327.75  Standard Class  1/16/2018    11:45
# 4  Smart watch          327.75  Standard Class  1/15/2018    11:24

# %%
# Convertimos la columna al formato datetime correcto
df_data["date"] = pd.to_datetime(df_data["date"]).dt.strftime("%m-%d-%Y")
df_data["datetime"] = pd.to_timedelta(df_data["datetime"] + ":00").astype(str).str[-8:-3]

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer             PR  5365 Noble Nectar Island              725
# 1         Consumer             PR          2679 Rustic Loop              725
# 2         Consumer             CA      8510 Round Bear Gate            95125
# 3      Home Office             CA           3200 Amber Bend            90027
# 4        Corporate             PR  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755   2018-01-31 22:56:00     77202
# 1         India              19492   2018-01-13 12:27:00     75939
# 2         India              19491   2018-01-13 12:06:00     75938
# 3     Australia              19490   2018-01-13 11:45:00     75937
# 4     Australia              19489   2018-01-13 11:24:00     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price   shipping_mode        date datetime
# 0  Smart watch          327.75  Standard Class  02-03-2018    22:56
# 1  Smart watch          327.75  Standard Class  01-18-2018    12:27
# 2  Smart watch          327.75  Standard Class  01-17-2018    12:06
# 3  Smart watch          327.75  Standard Class  01-16-2018    11:45
# 4  Smart watch          327.75  Standard Class  01-15-2018    11:24

# %% [markdown]
# #### Rellenar los nulos de la columna customer_lname por unknown

# %%
df_data["customer_lname"] = df_data["customer_lname"].fillna("Unknown")

# %%
df_data["customer_lname"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## ETL del dataset token

# %% [markdown]
# #### ver duplicados
