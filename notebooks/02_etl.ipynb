# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
import sys
import os # Esto sube un nivel en las carpetas para encontrar la raíz del proyecto
sys.path.append(os.path.abspath(os.path.join('..')))
import src.exploration as e
import src.transform as t

# %%
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_data = pd.read_csv("../files/raw/dataco_supply_chain.csv", sep=None, engine="python", encoding="latin-1")

# %%
df_data = t.standardize_columns(df_data)

# %%
df_data.sample(5)
# Out:
#             type  days_for_shipping_real  days_for_shipment_scheduled  \
# 122994  TRANSFER                       5                            2
# 176854     DEBIT                       1                            0
# 80771    PAYMENT                       6                            2
# 120854  TRANSFER                       6                            4
# 67805      DEBIT                       4                            4
#
#         benefit_per_order  sales_per_customer    delivery_status  \
# 122994          48.110001          178.169998  Shipping canceled
# 176854        -181.210007          106.589996      Late delivery
# 80771           58.799999          167.990005      Late delivery
# 120854          38.669998          110.489998      Late delivery
# 67805         -184.289993          230.360001   Shipping on time
#
#         late_delivery_risk  category_id        category_name customer_city  \
# 122994                   0           17               Cleats        Caguas
# 176854                   1           18       Men's Footwear        Caguas
# 80771                    1           48         Water Sports        Carson
# 120854                   1           18       Men's Footwear       Detroit
# 67805                    0            3  Baseball & Softball        Caguas
#
#        customer_country customer_email customer_fname  customer_id  \
# 122994      Puerto Rico      XXXXXXXXX           Mary        11430
# 176854      Puerto Rico      XXXXXXXXX           Mary         1448
# 80771           EE. UU.      XXXXXXXXX        Carolyn         4324
# 120854          EE. UU.      XXXXXXXXX           Mary        10157
# 67805       Puerto Rico      XXXXXXXXX           Mary         1130
#
#        customer_lname customer_password customer_segment customer_state  \
# 122994         Miller         XXXXXXXXX        Corporate             PR
# 176854         Murray         XXXXXXXXX         Consumer             PR
# 80771           Munoz         XXXXXXXXX         Consumer             CA
# 120854           Todd         XXXXXXXXX         Consumer             MI
# 67805         Johnson         XXXXXXXXX        Corporate             PR
#
#               customer_street  customer_zipcode  department_id  \
# 122994      9854 Wishing Isle             725.0              4
# 176854   7732 Lazy View Crest             725.0              4
# 80771    777 Sleepy Quail Key           90745.0              7
# 120854  403 Cozy Spring Farms           48205.0              4
# 67805     1690 Blue Dale Lane             725.0              2
#
#        department_name   latitude   longitude        market  order_city  \
# 122994         Apparel  18.293554  -66.370583          USCA  Louisville
# 176854         Apparel  18.262333  -66.370544          USCA      Athens
# 80771         Fan Shop  33.831795 -118.261322  Pacific Asia    Adelaide
# 120854         Apparel  42.428772  -82.982529        Europe     Palermo
# 67805          Fitness  18.205925  -66.370499         LATAM       Mixco
#
#          order_country  order_customer_id order_date_dateorders  order_id  \
# 122994  Estados Unidos              11430        6/18/2016 0:39     36584
# 176854  Estados Unidos               1448       6/23/2016 19:02     36979
# 80771        Australia               4324        2/17/2016 5:22     28240
# 120854          Italia              10157        7/19/2017 5:21     63725
# 67805        Guatemala               1130       4/13/2017 16:52     57113
#
#         order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 122994                     365                  1.8                      0.01
# 176854                     403                 23.4                      0.18
# 80771                     1073                 32.0                      0.16
# 120854                     403                 19.5                      0.15
# 67805                       44                  9.6                      0.04
#
#         order_item_id  order_item_product_price  order_item_profit_ratio  \
# 122994          91313                 59.990002                     0.27
# 176854          92287                129.990005                    -1.70
# 80771           70632                199.990005                     0.35
# 120854         159297                129.990005                     0.35
# 67805          142854                 59.990002                    -0.80
#
#         order_item_quantity       sales  order_item_total  \
# 122994                    3  179.970001        178.169998
# 176854                    1  129.990005        106.589996
# 80771                     1  199.990005        167.990005
# 120854                    1  129.990005        110.489998
# 67805                     4  239.960007        230.360001
#
#         order_profit_per_order     order_region        order_state  \
# 122994               48.110001     West of USA            Colorado
# 176854             -181.210007   South of  USA             Georgia
# 80771                58.799999          Oceania  Australia del Sur
# 120854               38.669998  Southern Europe            Sicilia
# 67805              -184.289993  Central America          Guatemala
#
#            order_status  order_zipcode  product_card_id  product_category_id  \
# 122994  SUSPECTED_FRAUD        80027.0              365                   17
# 176854         COMPLETE        30605.0              403                   18
# 80771   PENDING_PAYMENT            NaN             1073                   48
# 120854       PROCESSING            NaN              403                   18
# 67805          COMPLETE            NaN               44                    3
#
#         product_description  \
# 122994                  NaN
# 176854                  NaN
# 80771                   NaN
# 120854                  NaN
# 67805                   NaN
#
#                                             product_image  \
# 122994  http://images.acmesports.sports/Perfect+Fitnes...
# 176854  http://images.acmesports.sports/Nike+Men%27s+C...
# 80771   http://images.acmesports.sports/Pelican+Sunstr...
# 120854  http://images.acmesports.sports/Nike+Men%27s+C...
# 67805   http://images.acmesports.sports/adidas+Men%27s...
#
#                                       product_name  product_price  \
# 122994            Perfect Fitness Perfect Rip Deck      59.990002
# 176854     Nike Men's CJ Elite 2 TD Football Cleat     129.990005
# 80771                  Pelican Sunstream 100 Kayak     199.990005
# 120854     Nike Men's CJ Elite 2 TD Football Cleat     129.990005
# 67805   adidas Men's F10 Messi TRX FG Soccer Cleat      59.990002
#
#         product_status shipping_date_dateorders   shipping_mode
# 122994               0           6/23/2016 0:39    Second Class
# 176854               0           6/24/2016 7:02        Same Day
# 80771                0           2/23/2016 5:22    Second Class
# 120854               0           7/25/2017 5:21  Standard Class
# 67805                0          4/17/2017 16:52  Standard Class

# %% [markdown]
# #### Eliminar columnas

# %%
df_data.drop(columns=["product_status", "customer_email", "customer_password", "product_description", "order_zipcode", "market", "order_state","product_image"],inplace=True)

# %% [markdown]
# #### Cambiar los códigos por abreviaturas del estado

# %%
dicc_ca = {"95758" : "CA", "91732" : "CA"}

df_data["customer_state"] = df_data["customer_state"].map(dicc_ca).fillna(df_data["customer_state"])

# %%
df_data["customer_state"].unique()
# Out:
# <StringArray>
# ['PR', 'CA', 'NY', 'FL', 'MA', 'IL', 'MT', 'PA', 'MI', 'TX', 'DE', 'GA', 'MD',
#  'OH', 'HI', 'NJ', 'WI', 'AZ', 'CO', 'MN', 'NC', 'NM', 'OR', 'SC', 'VA', 'UT',
#  'WA', 'KY', 'WV', 'RI', 'CT', 'LA', 'TN', 'DC', 'ND', 'MO', 'IN', 'ID', 'NV',
#  'KS', 'AR', 'OK', 'AL', 'IA']
# Length: 44, dtype: str

# %% [markdown]
# #### Cambiar las abreviaturas por el nombre del estado

# %%
state_mapping = {
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'PR': 'Puerto Rico',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia'
}

# %%
df_data["customer_state"] = df_data["customer_state"].map(state_mapping)

# %% [markdown]
# #### Convertir tipos de datos

# %%
df_data["customer_zipcode"] = df_data["customer_zipcode"].astype(str).str.replace(".0", "", regex=False)

# %%
df_data["order_item_discount"] = df_data["order_item_discount"].astype(float)

# %% [markdown]
# #### Rellenar los 3 nulos de la columna customer_zipcode usando la latitud y la longitud

# %%
# 1

df_data.loc[np.isclose(df_data["latitude"], 39.134159) & np.isclose(df_data["longitude"], -123.718552),"customer_zipcode"] = "95410"
 
# 2

df_data.loc[np.isclose(df_data["latitude"], 38.408573) & np.isclose(df_data["longitude"], -121.449112),"customer_zipcode"] = "95823"
 
# 3

df_data.loc[np.isclose(df_data["latitude"], 34.071892) & np.isclose(df_data["longitude"], -118.013886),"customer_zipcode"] = "91732"

# %% [markdown]
# #### Aplicar función para redondear los decimales

# %%
t.round_up(df_data)

df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer    Puerto Rico  5365 Noble Nectar Island              725
# 1         Consumer    Puerto Rico          2679 Rustic Loop              725
# 2         Consumer     California      8510 Round Bear Gate            95125
# 3      Home Office     California           3200 Amber Bend            90027
# 4        Corporate    Puerto Rico  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755       1/31/2018 22:56     77202
# 1         India              19492       1/13/2018 12:27     75939
# 2         India              19491       1/13/2018 12:06     75938
# 3     Australia              19490       1/13/2018 11:45     75937
# 4     Australia              19489       1/13/2018 11:24     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price shipping_date_dateorders   shipping_mode
# 0  Smart watch          327.75           2/3/2018 22:56  Standard Class
# 1  Smart watch          327.75          1/18/2018 12:27  Standard Class
# 2  Smart watch          327.75          1/17/2018 12:06  Standard Class
# 3  Smart watch          327.75          1/16/2018 11:45  Standard Class
# 4  Smart watch          327.75          1/15/2018 11:24  Standard Class

# %% [markdown]
# #### Dividir una columna en dos, fecha y hora y cambiar el formato

# %%
df_data['delivery_date'] = df_data['shipping_date_dateorders'].str.split(' ').str[0]

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer    Puerto Rico  5365 Noble Nectar Island              725
# 1         Consumer    Puerto Rico          2679 Rustic Loop              725
# 2         Consumer     California      8510 Round Bear Gate            95125
# 3      Home Office     California           3200 Amber Bend            90027
# 4        Corporate    Puerto Rico  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755       1/31/2018 22:56     77202
# 1         India              19492       1/13/2018 12:27     75939
# 2         India              19491       1/13/2018 12:06     75938
# 3     Australia              19490       1/13/2018 11:45     75937
# 4     Australia              19489       1/13/2018 11:24     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price shipping_date_dateorders   shipping_mode  \
# 0  Smart watch          327.75           2/3/2018 22:56  Standard Class
# 1  Smart watch          327.75          1/18/2018 12:27  Standard Class
# 2  Smart watch          327.75          1/17/2018 12:06  Standard Class
# 3  Smart watch          327.75          1/16/2018 11:45  Standard Class
# 4  Smart watch          327.75          1/15/2018 11:24  Standard Class
#
#   delivery_date
# 0      2/3/2018
# 1     1/18/2018
# 2     1/17/2018
# 3     1/16/2018
# 4     1/15/2018

# %%
df_data.drop(columns=["shipping_date_dateorders"],inplace=True)

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer    Puerto Rico  5365 Noble Nectar Island              725
# 1         Consumer    Puerto Rico          2679 Rustic Loop              725
# 2         Consumer     California      8510 Round Bear Gate            95125
# 3      Home Office     California           3200 Amber Bend            90027
# 4        Corporate    Puerto Rico  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755       1/31/2018 22:56     77202
# 1         India              19492       1/13/2018 12:27     75939
# 2         India              19491       1/13/2018 12:06     75938
# 3     Australia              19490       1/13/2018 11:45     75937
# 4     Australia              19489       1/13/2018 11:24     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price   shipping_mode delivery_date
# 0  Smart watch          327.75  Standard Class      2/3/2018
# 1  Smart watch          327.75  Standard Class     1/18/2018
# 2  Smart watch          327.75  Standard Class     1/17/2018
# 3  Smart watch          327.75  Standard Class     1/16/2018
# 4  Smart watch          327.75  Standard Class     1/15/2018

# %%
# Convertimos la columna al formato datetime correcto
df_data["delivery_date"] = pd.to_datetime(df_data["delivery_date"]).dt.strftime("%m-%d-%Y")

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer    Puerto Rico  5365 Noble Nectar Island              725
# 1         Consumer    Puerto Rico          2679 Rustic Loop              725
# 2         Consumer     California      8510 Round Bear Gate            95125
# 3      Home Office     California           3200 Amber Bend            90027
# 4        Corporate    Puerto Rico  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755       1/31/2018 22:56     77202
# 1         India              19492       1/13/2018 12:27     75939
# 2         India              19491       1/13/2018 12:06     75938
# 3     Australia              19490       1/13/2018 11:45     75937
# 4     Australia              19489       1/13/2018 11:24     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price   shipping_mode delivery_date
# 0  Smart watch          327.75  Standard Class    02-03-2018
# 1  Smart watch          327.75  Standard Class    01-18-2018
# 2  Smart watch          327.75  Standard Class    01-17-2018
# 3  Smart watch          327.75  Standard Class    01-16-2018
# 4  Smart watch          327.75  Standard Class    01-15-2018

# %%
df_data[['order_date', 'order_time']] = df_data['order_date_dateorders'].str.split(' ', expand=True)

# %%
df_data.head()
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
#
#    benefit_per_order  sales_per_customer   delivery_status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    late_delivery_risk  category_id   category_name customer_city  \
# 0                   0           73  Sporting Goods        Caguas
# 1                   1           73  Sporting Goods        Caguas
# 2                   0           73  Sporting Goods      San Jose
# 3                   0           73  Sporting Goods   Los Angeles
# 4                   0           73  Sporting Goods        Caguas
#
#   customer_country customer_fname  customer_id customer_lname  \
# 0      Puerto Rico          Cally        20755       Holloway
# 1      Puerto Rico          Irene        19492           Luna
# 2          EE. UU.        Gillian        19491      Maldonado
# 3          EE. UU.           Tana        19490           Tate
# 4      Puerto Rico           Orli        19489      Hendricks
#
#   customer_segment customer_state           customer_street customer_zipcode  \
# 0         Consumer    Puerto Rico  5365 Noble Nectar Island              725
# 1         Consumer    Puerto Rico          2679 Rustic Loop              725
# 2         Consumer     California      8510 Round Bear Gate            95125
# 3      Home Office     California           3200 Amber Bend            90027
# 4        Corporate    Puerto Rico  8671 Iron Anchor Corners              725
#
#    department_id department_name   latitude   longitude  order_city  \
# 0              2         Fitness  18.251453  -66.037056      Bekasi
# 1              2         Fitness  18.279451  -66.037064     Bikaner
# 2              2         Fitness  37.292233 -121.881279     Bikaner
# 3              2         Fitness  34.125946 -118.291016  Townsville
# 4              2         Fitness  18.253769  -66.037048  Townsville
#
#   order_country  order_customer_id order_date_dateorders  order_id  \
# 0     Indonesia              20755       1/31/2018 22:56     77202
# 1         India              19492       1/13/2018 12:27     75939
# 2         India              19491       1/13/2018 12:06     75938
# 3     Australia              19490       1/13/2018 11:45     75937
# 4     Australia              19489       1/13/2018 11:24     75936
#
#    order_item_cardprod_id  order_item_discount  order_item_discount_rate  \
# 0                    1360                13.11                      0.04
# 1                    1360                16.39                      0.05
# 2                    1360                18.03                      0.06
# 3                    1360                22.94                      0.07
# 4                    1360                29.50                      0.09
#
#    order_item_id  order_item_product_price  order_item_profit_ratio  \
# 0         180517                    327.75                     0.29
# 1         179254                    327.75                    -0.80
# 2         179253                    327.75                    -0.80
# 3         179252                    327.75                     0.08
# 4         179251                    327.75                     0.45
#
#    order_item_quantity   sales  order_item_total  order_profit_per_order  \
# 0                    1  327.75            314.64                   91.25
# 1                    1  327.75            311.36                 -249.09
# 2                    1  327.75            309.72                 -247.78
# 3                    1  327.75            304.81                   22.86
# 4                    1  327.75            298.25                  134.21
#
#      order_region     order_status  product_card_id  product_category_id  \
# 0  Southeast Asia         COMPLETE             1360                   73
# 1      South Asia          PENDING             1360                   73
# 2      South Asia           CLOSED             1360                   73
# 3         Oceania         COMPLETE             1360                   73
# 4         Oceania  PENDING_PAYMENT             1360                   73
#
#    product_name  product_price   shipping_mode delivery_date order_date  \
# 0  Smart watch          327.75  Standard Class    02-03-2018  1/31/2018
# 1  Smart watch          327.75  Standard Class    01-18-2018  1/13/2018
# 2  Smart watch          327.75  Standard Class    01-17-2018  1/13/2018
# 3  Smart watch          327.75  Standard Class    01-16-2018  1/13/2018
# 4  Smart watch          327.75  Standard Class    01-15-2018  1/13/2018
#
#   order_time
# 0      22:56
# 1      12:27
# 2      12:06
# 3      11:45
# 4      11:24

# %%
df_data.drop(columns=['order_date_dateorders'],inplace=True)

# %% [markdown]
# Cambios formatos de hora

# %%
# Convertimos la columna al formato datetime correcto
df_data["order_date"] = pd.to_datetime(df_data["order_date"]).dt.strftime("%m-%d-%Y")
df_data["order_time"] = pd.to_timedelta(df_data["order_time"] + ":00").astype(str).str[-8:-3]

# %% [markdown]
# #### Rellenar los nulos de la columna customer_lname por unknown

# %%
df_data["customer_lname"] = df_data["customer_lname"].fillna("Unknown")

# %%
df_data["customer_lname"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Cambio de formato columnas de país

# %%
df_data["order_country"] = df_data["order_country"].str.lower()

# %%
sorted(df_data["order_country"].unique().tolist())
# Out:
# ['afganistán',
#  'albania',
#  'alemania',
#  'angola',
#  'arabia saudí',
#  'argelia',
#  'argentina',
#  'armenia',
#  'australia',
#  'austria',
#  'azerbaiyán',
#  'bangladés',
#  'barbados',
#  'baréin',
#  'belice',
#  'benín',
#  'bielorrusia',
#  'bolivia',
#  'bosnia y herzegovina',
#  'botsuana',
#  'brasil',
#  'bulgaria',
#  'burkina faso',
#  'burundi',
#  'bután',
#  'bélgica',
#  'camboya',
#  'camerún',
#  'canada',
#  'chad',
#  'chile',
#  'china',
#  'chipre',
#  'colombia',
#  'corea del sur',
#  'costa de marfil',
#  'costa rica',
#  'croacia',
#  'cuba',
#  'dinamarca',
#  'ecuador',
#  'egipto',
#  'el salvador',
#  'emiratos árabes unidos',
#  'eritrea',
#  'eslovaquia',
#  'eslovenia',
#  'españa',
#  'estados unidos',
#  'estonia',
#  'etiopía',
#  'filipinas',
#  'finlandia',
#  'francia',
#  'gabón',
#  'georgia',
#  'ghana',
#  'grecia',
#  'guadalupe',
#  'guatemala',
#  'guayana francesa',
#  'guinea',
#  'guinea ecuatorial',
#  'guinea-bissau',
#  'guyana',
#  'haití',
#  'honduras',
#  'hong kong',
#  'hungría',
#  'india',
#  'indonesia',
#  'irak',
#  'irlanda',
#  'irán',
#  'israel',
#  'italia',
#  'jamaica',
#  'japón',
#  'jordania',
#  'kazajistán',
#  'kenia',
#  'kirguistán',
#  'kuwait',
#  'laos',
#  'lesoto',
#  'liberia',
#  'libia',
#  'lituania',
#  'luxemburgo',
#  'líbano',
#  'macedonia',
#  'madagascar',
#  'malasia',
#  'mali',
#  'marruecos',
#  'martinica',
#  'mauritania',
#  'moldavia',
#  'mongolia',
#  'montenegro',
#  'mozambique',
#  'myanmar (birmania)',
#  'méxico',
#  'namibia',
#  'nepal',
#  'nicaragua',
#  'nigeria',
#  'noruega',
#  'nueva zelanda',
#  'níger',
#  'omán',
#  'pakistán',
#  'panamá',
#  'papúa nueva guinea',
#  'paraguay',
#  'países bajos',
#  'perú',
#  'polonia',
#  'portugal',
#  'qatar',
#  'reino unido',
#  'república centroafricana',
#  'república checa',
#  'república de gambia',
#  'república del congo',
#  'república democrática del congo',
#  'república dominicana',
#  'ruanda',
#  'rumania',
#  'rusia',
#  'senegal',
#  'serbia',
#  'sierra leona',
#  'singapur',
#  'siria',
#  'somalia',
#  'sri lanka',
#  'suazilandia',
#  'sudafrica',
#  'sudán',
#  'sudán del sur',
#  'suecia',
#  'suiza',
#  'surinam',
#  'sáhara occidental',
#  'tailandia',
#  'taiwán',
#  'tanzania',
#  'tayikistán',
#  'togo',
#  'trinidad y tobago',
#  'turkmenistán',
#  'turquía',
#  'túnez',
#  'ucrania',
#  'uganda',
#  'uruguay',
#  'uzbekistán',
#  'venezuela',
#  'vietnam',
#  'yemen',
#  'yibuti',
#  'zambia',
#  'zimbabue']

# %%
df_data["order_country"] = df_data["order_country"].str.title()

# %%
sorted(df_data["order_country"].unique().tolist())
# Out:
# ['Afganistán',
#  'Albania',
#  'Alemania',
#  'Angola',
#  'Arabia Saudí',
#  'Argelia',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaiyán',
#  'Bangladés',
#  'Barbados',
#  'Baréin',
#  'Belice',
#  'Benín',
#  'Bielorrusia',
#  'Bolivia',
#  'Bosnia Y Herzegovina',
#  'Botsuana',
#  'Brasil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Bután',
#  'Bélgica',
#  'Camboya',
#  'Camerún',
#  'Canada',
#  'Chad',
#  'Chile',
#  'China',
#  'Chipre',
#  'Colombia',
#  'Corea Del Sur',
#  'Costa De Marfil',
#  'Costa Rica',
#  'Croacia',
#  'Cuba',
#  'Dinamarca',
#  'Ecuador',
#  'Egipto',
#  'El Salvador',
#  'Emiratos Árabes Unidos',
#  'Eritrea',
#  'Eslovaquia',
#  'Eslovenia',
#  'España',
#  'Estados Unidos',
#  'Estonia',
#  'Etiopía',
#  'Filipinas',
#  'Finlandia',
#  'Francia',
#  'Gabón',
#  'Georgia',
#  'Ghana',
#  'Grecia',
#  'Guadalupe',
#  'Guatemala',
#  'Guayana Francesa',
#  'Guinea',
#  'Guinea Ecuatorial',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haití',
#  'Honduras',
#  'Hong Kong',
#  'Hungría',
#  'India',
#  'Indonesia',
#  'Irak',
#  'Irlanda',
#  'Irán',
#  'Israel',
#  'Italia',
#  'Jamaica',
#  'Japón',
#  'Jordania',
#  'Kazajistán',
#  'Kenia',
#  'Kirguistán',
#  'Kuwait',
#  'Laos',
#  'Lesoto',
#  'Liberia',
#  'Libia',
#  'Lituania',
#  'Luxemburgo',
#  'Líbano',
#  'Macedonia',
#  'Madagascar',
#  'Malasia',
#  'Mali',
#  'Marruecos',
#  'Martinica',
#  'Mauritania',
#  'Moldavia',
#  'Mongolia',
#  'Montenegro',
#  'Mozambique',
#  'Myanmar (Birmania)',
#  'México',
#  'Namibia',
#  'Nepal',
#  'Nicaragua',
#  'Nigeria',
#  'Noruega',
#  'Nueva Zelanda',
#  'Níger',
#  'Omán',
#  'Pakistán',
#  'Panamá',
#  'Papúa Nueva Guinea',
#  'Paraguay',
#  'Países Bajos',
#  'Perú',
#  'Polonia',
#  'Portugal',
#  'Qatar',
#  'Reino Unido',
#  'República Centroafricana',
#  'República Checa',
#  'República De Gambia',
#  'República Del Congo',
#  'República Democrática Del Congo',
#  'República Dominicana',
#  'Ruanda',
#  'Rumania',
#  'Rusia',
#  'Senegal',
#  'Serbia',
#  'Sierra Leona',
#  'Singapur',
#  'Siria',
#  'Somalia',
#  'Sri Lanka',
#  'Suazilandia',
#  'Sudafrica',
#  'Sudán',
#  'Sudán Del Sur',
#  'Suecia',
#  'Suiza',
#  'Surinam',
#  'Sáhara Occidental',
#  'Tailandia',
#  'Taiwán',
#  'Tanzania',
#  'Tayikistán',
#  'Togo',
#  'Trinidad Y Tobago',
#  'Turkmenistán',
#  'Turquía',
#  'Túnez',
#  'Ucrania',
#  'Uganda',
#  'Uruguay',
#  'Uzbekistán',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Yibuti',
#  'Zambia',
#  'Zimbabue']

# %%
df_data.to_csv("../files/processed/dataco_supply_chain.csv", index=False)

# %% [markdown]
# ## ETL del dataset token

# %% [markdown]
# #### ver duplicados

# %%
df_token = pd.read_csv("../files/raw/tokenized_access_logs.csv")

# %%
df_token[df_token.duplicated(keep=False)].value_counts()
# Out:
# Product                                  Category              Date             Month  Hour  Department  ip              url
# Nike Men's CJ Elite 2 TD Football Cleat  men's footwear        9/14/2017 20:31  Sep    20    apparel     147.29.196.147  /department/apparel/category/men's%20footwear/product/Nike%20Men's%20CJ%20Elite%202%20TD%20Football%20Cleat            5
# O'Brien Men's Neoprene Life Vest         indoor outdoor games  9/14/2017 11:20  Sep    11    fan shop    202.226.31.11   /department/fan%20shop/category/indoor/outdoor%20games/product/O'Brien%20Men's%20Neoprene%20Life%20Vest                4
# Nike Men's Free TR 5.0 TB Training Shoe  as seen on  tv!       9/14/2017 12:28  Sep    12    footwear    138.45.174.221  /department/footwear/category/as%20seen%20on%20%20tv!/product/Nike%20Men's%20Free%20TR%205.0%20TB%20Training%20Shoe    4
# Nike Men's Fingertrap Max Training Shoe  soccer                9/14/2017 18:09  Sep    18    fitness     10.184.28.55    /department/fitness/category/soccer/product/Nike%20Men's%20Fingertrap%20Max%20Training%20Shoe                          4
# Nike Men's Dri-FIT Victory Golf Polo     women's apparel       9/14/2017 19:15  Sep    19    golf        36.85.174.235   /department/golf/category/women's%20apparel/product/Nike%20Men's%20Dri-FIT%20Victory%20Golf%20Polo                     4
#                                                                                                                                                                                                                                                ..
# Nike Men's CJ Elite 2 TD Football Cleat  men's footwear        10/6/2017 8:12   Oct    8     apparel     58.20.180.169   /department/apparel/category/men's%20footwear/product/Nike%20Men's%20CJ%20Elite%202%20TD%20Football%20Cleat            2
# TYR Boys' Team Digi Jammer               girls' apparel        10/6/2017 12:17  Oct    12    golf        194.22.243.107  /department/golf/category/girls'%20apparel/product/TYR%20Boys'%20Team%20Digi%20Jammer                                  2
# Perfect Fitness Perfect Rip Deck         cleats                10/7/2017 20:48  Oct    20    apparel     95.234.113.98   /department/apparel/category/cleats/product/Perfect%20Fitness%20Perfect%20Rip%20Deck                                   2
# Nike Men's Dri-FIT Victory Golf Polo     women's apparel       10/7/2017 21:40  Oct    21    golf        34.175.52.9     /department/golf/category/women's%20apparel/product/Nike%20Men's%20Dri-FIT%20Victory%20Golf%20Polo                     2
# Nike Men's CJ Elite 2 TD Football Cleat  men's footwear        10/9/2017 12:56  Oct    12    apparel     105.58.81.244   /department/apparel/category/men's%20footwear/product/Nike%20Men's%20CJ%20Elite%202%20TD%20Football%20Cleat            2
# Name: count, Length: 3046, dtype: int64

# %% [markdown]
# #### Borrar duplicados

# %%
df_token.drop_duplicates(inplace=True)

# %%
df_token.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Borrar columnas

# %%
df_token.columns
# Out:
# Index(['Product', 'Category', 'Date', 'Month', 'Hour', 'Department', 'ip',
#        'url'],
#       dtype='str')

# %%
df_token = df_token.drop(['Month', 'Hour', 'url'], axis=1)

# %%
df_token.columns
# Out:
# Index(['Product', 'Category', 'Date', 'Department', 'ip'], dtype='str')

# %%
df_token.head()
# Out:
#                                       Product             Category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             Date Department              ip
# 0  9/1/2017 6:00   fitness     37.97.182.65
# 1  9/1/2017 6:00  fan shop     206.56.112.1
# 2  9/1/2017 6:00   apparel    215.143.180.0
# 3  9/1/2017 6:00  footwear     206.56.112.1
# 4  9/1/2017 6:01  fan shop   136.108.56.242

# %% [markdown]
# #### Estandarizar nombres columnas

# %%
df_token = t.standardize_columns(df_token)

# %%
df_token.head()
# Out:
#                                       product             category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             date department              ip
# 0  9/1/2017 6:00   fitness     37.97.182.65
# 1  9/1/2017 6:00  fan shop     206.56.112.1
# 2  9/1/2017 6:00   apparel    215.143.180.0
# 3  9/1/2017 6:00  footwear     206.56.112.1
# 4  9/1/2017 6:01  fan shop   136.108.56.242

# %% [markdown]
# #### Dividir una columna en dos, fecha y hora y cambiar el formato

# %%
df_token[['date2', 'datetime']] = df_token['date'].str.split(' ', expand=True)

# %%
df_token.head()
# Out:
#                                       product             category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             date department              ip     date2 datetime
# 0  9/1/2017 6:00   fitness     37.97.182.65  9/1/2017     6:00
# 1  9/1/2017 6:00  fan shop     206.56.112.1  9/1/2017     6:00
# 2  9/1/2017 6:00   apparel    215.143.180.0  9/1/2017     6:00
# 3  9/1/2017 6:00  footwear     206.56.112.1  9/1/2017     6:00
# 4  9/1/2017 6:01  fan shop   136.108.56.242  9/1/2017     6:01

# %%
df_token.drop(columns='date',inplace=True)

# %%
df_token.head()
# Out:
#                                       product             category department  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball   fitness
# 1       The North Face Women's Recon Backpack   hunting & shooting  fan shop
# 2      adidas Kids' RG III Mid Football Cleat       featured shops   apparel
# 3  Under Armour Men's Compression EV SL Slide          electronics  footwear
# 4                 Pelican Sunstream 100 Kayak         water sports  fan shop
#
#                ip     date2 datetime
# 0    37.97.182.65  9/1/2017     6:00
# 1    206.56.112.1  9/1/2017     6:00
# 2   215.143.180.0  9/1/2017     6:00
# 3    206.56.112.1  9/1/2017     6:00
# 4  136.108.56.242  9/1/2017     6:01

# %%
df_token.rename(columns={'date2':'date'}, inplace=True)

# %%
df_token.head()
# Out:
#                                       product             category department  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball   fitness
# 1       The North Face Women's Recon Backpack   hunting & shooting  fan shop
# 2      adidas Kids' RG III Mid Football Cleat       featured shops   apparel
# 3  Under Armour Men's Compression EV SL Slide          electronics  footwear
# 4                 Pelican Sunstream 100 Kayak         water sports  fan shop
#
#                ip      date datetime
# 0    37.97.182.65  9/1/2017     6:00
# 1    206.56.112.1  9/1/2017     6:00
# 2   215.143.180.0  9/1/2017     6:00
# 3    206.56.112.1  9/1/2017     6:00
# 4  136.108.56.242  9/1/2017     6:01

# %%
# Convertimos la columna al formato datetime correcto
df_token["date"] = pd.to_datetime(df_token["date"]).dt.strftime("%m-%d-%Y")
df_token["datetime"] = pd.to_timedelta(df_token["datetime"] + ":00").astype(str).str[-8:-3]

# %%
df_token.head()
# Out:
#                                       product             category department  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball   fitness
# 1       The North Face Women's Recon Backpack   hunting & shooting  fan shop
# 2      adidas Kids' RG III Mid Football Cleat       featured shops   apparel
# 3  Under Armour Men's Compression EV SL Slide          electronics  footwear
# 4                 Pelican Sunstream 100 Kayak         water sports  fan shop
#
#                ip        date datetime
# 0    37.97.182.65  09-01-2017    06:00
# 1    206.56.112.1  09-01-2017    06:00
# 2   215.143.180.0  09-01-2017    06:00
# 3    206.56.112.1  09-01-2017    06:00
# 4  136.108.56.242  09-01-2017    06:01

# %%
df_token.to_csv("../files/processed/token_access_logs.csv", index=False, encoding="utf-8")
